# %%
from gensim.corpora.wikicorpus import tokenize

text = "Đền Lolei tại Angkor, Campuchia Lolei là ngôi đền cực bắc của nhóm Roluos tại Angkor, Campuchia. Nó được xây vào cuối thế kỷ 9 dưới thời vua Yasovarman I. Đây là một ngôi đền trên đảo, nằm hơi chếch về phía bắc của trung tâm baray Indratataka, mà việc xây dựng baray này hầu như đã hoàn tất dưới thời vua trước đó, Indravarman I. Baray này hiện đang khô ráo."
tokenize(text)
# Out:
# ['đền',
#  'lolei',
#  'tại',
#  'angkor',
#  'campuchia',
#  'lolei',
#  'là',
#  'ngôi',
#  'đền',
#  'cực',
#  'bắc',
#  'của',
#  'nhóm',
#  'roluos',
#  'tại',
#  'angkor',
#  'campuchia',
#  'nó',
#  'được',
#  'xây',
#  'vào',
#  'cuối',
#  'thế',
#  'kỷ',
#  'dưới',
#  'thời',
#  'vua',
#  'yasovarman',
#  'đây',
#  'là',
#  'một',
#  'ngôi',
#  'đền',
#  'trên',
#  'đảo',
#  'nằm',
#  'hơi',
#  'chếch',
#  'về',
#  'phía',
#  'bắc',
#  'của',
#  'trung',
#  'tâm',
#  'baray',
#  'indratataka',
#  'mà',
#  'việc',
#  'xây',
#  'dựng',
#  'baray',
#  'này',
#  'hầu',
#  'như',
#  'đã',
#  'hoàn',
#  'tất',
#  'dưới',
#  'thời',
#  'vua',
#  'trước',
#  'đó',
#  'indravarman',
#  'baray',
#  'này',
#  'hiện',
#  'đang',
#  'khô',
#  'ráo']
